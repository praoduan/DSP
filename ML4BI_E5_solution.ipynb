# %% [markdown]
# <a href="https://colab.research.google.com/github/praoduan/DSP/blob/main/ML4BI_E5_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning for BI 2
#
# ## Deep Learning exercises for week 6
#
# In this exercise, you will expand last weeks exercise by training pre-trained model

# %% [markdown]
# **About the CIFAR-10 dataset**
#
# The CIFAR-10 dataset is a widely-used dataset for benchmarking machine learning algorithms, especially in the field of image recognition. It consists of 60,000 32x32 color images in 10 different classes, with 6,000 images per class. The dataset is divided into 50,000 training images and 10,000 test images. The classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. Each image is labeled with one of these 10 classes, making it a standard dataset for evaluating algorithms for image classification tasks.
#
# The CIFAR-10 dataset was created by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton and is a subset of the 80 million tiny images dataset. Due to its moderate size and complexity, CIFAR-10 serves as an excellent benchmark for algorithms and techniques in computer vision, particularly for methodologies that are aimed at performing well on small to medium-sized datasets in image recognition tasks.

# %% [markdown]
# **Load and prepare the data**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# Load the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Class names in the CIFAR-10 dataset
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step

# %% [markdown]
# **Plot images**
#
# Plot some images from the dataset.

# %%
import numpy as np

# Initialize a plot with 1 row and 10 columns
fig, axes = plt.subplots(2, 5, figsize=(14, 6))
axes = axes.ravel()

# Plot one image from each class
for i in range(10):
    # Find the index of the first image of each class
    index = np.where(train_labels.flatten() == i)[0][0]
    img = train_images[index]

    # Plot the image
    axes[i].imshow(img, cmap=plt.cm.binary)
    axes[i].set_title(class_names[i])
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# very hard to figure out with human eyes.
# these photos have noises eg. background, size >> should do augmentation

# %%
# Convert labels to one-hot encoding
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# **Model building**
#
# Build a convnet without adding data augmentation.

# %%
inputs = tf.keras.Input(shape=(32, 32, 3))  # Input layer

# Normalization layer
x = layers.Rescaling(1./255)(inputs)

# First Convolutional Block
x = layers.Conv2D(32, (3, 3), activation='relu')(x) #conV layer for sliding kernels across images
x = layers.MaxPooling2D((2, 2))(x)

# Second Convolutional Block
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

# Third Convolutional Block
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x) #eachtime we're increasing number of feature map 32 > 64 >128
# then flatten to only represented only one big vector ~ removing slowing things that are not important by pooling and conv

# Flatten and Dense Layers
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(10, activation='softmax')(x)  # 10 classes in CIFAR-10 (10 images of diff type)

# Model creation
model = models.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  rescaling (Rescaling)       (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 64)                32832
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 126730 (495.04 KB)
# Trainable params: 126730 (495.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Compile and train the model**

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(train_images, train_labels, epochs=50,
                    validation_split=0.2, batch_size=256, #20% validation split instead of manually create validation data
                    callbacks = callbacks)
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.2234 - loss: 2.0740 - val_accuracy: 0.3686 - val_loss: 1.7518
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3967 - loss: 1.6673 - val_accuracy: 0.4176 - val_loss: 1.5800
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4449 - loss: 1.5265 - val_accuracy: 0.4739 - val_loss: 1.4318
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4723 - loss: 1.4710 - val_accuracy: 0.4833 - val_loss: 1.4790
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4904 - loss: 1.4071 - val_accuracy: 0.5172 - val_loss: 1.3718
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5077 - loss: 1.3728 - val_accuracy: 0.4895 - val_loss: 1.4882
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5304 - loss: 1.3195 - val_accuracy: 0.5458 - val_loss: 1.2711
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5441 - loss: 1.2880 - val_accuracy: 0.5675 - val_loss: 1.2499
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5505 - loss: 1.2530 - val_accuracy: 0.5858 - val_loss: 1.1943
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5645 - loss: 1.2278 - val_accuracy: 0.5545 - val_loss: 1.3040
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5702 - loss: 1.2097 - val_accuracy: 0.6030 - val_loss: 1.1220
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5814 - loss: 1.1890 - val_accuracy: 0.6136 - val_loss: 1.1254
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5888 - loss: 1.1705 - val_accuracy: 0.5787 - val_loss: 1.2407
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5899 - loss: 1.1661 - val_accuracy: 0.6086 - val_loss: 1.1325
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6037 - loss: 1.1204 - val_accuracy: 0.5824 - val_loss: 1.2525
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6099 - loss: 1.1117 - val_accuracy: 0.5937 - val_loss: 1.2196
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6093 - loss: 1.0992 - val_accuracy: 0.6045 - val_loss: 1.1445
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6162 - loss: 1.0871 - val_accuracy: 0.6258 - val_loss: 1.0822
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6183 - loss: 1.0810 - val_accuracy: 0.6525 - val_loss: 1.0056
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6305 - loss: 1.0458 - val_accuracy: 0.6294 - val_loss: 1.0638
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6337 - loss: 1.0494 - val_accuracy: 0.6476 - val_loss: 1.0088
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6362 - loss: 1.0381 - val_accuracy: 0.6219 - val_loss: 1.1090
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6406 - loss: 1.0380 - val_accuracy: 0.6521 - val_loss: 1.0132
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6447 - loss: 1.0145 - val_accuracy: 0.6414 - val_loss: 1.0495
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6451 - loss: 1.0086 - val_accuracy: 0.6640 - val_loss: 0.9757
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6509 - loss: 0.9926 - val_accuracy: 0.6479 - val_loss: 1.0437
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6493 - loss: 0.9934 - val_accuracy: 0.6654 - val_loss: 0.9793
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6569 - loss: 0.9806 - val_accuracy: 0.6784 - val_loss: 0.9430
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6557 - loss: 0.9793 - val_accuracy: 0.6649 - val_loss: 0.9836
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6628 - loss: 0.9560 - val_accuracy: 0.6473 - val_loss: 1.0385
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6672 - loss: 0.9604 - val_accuracy: 0.6743 - val_loss: 0.9740
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6625 - loss: 0.9500 - val_accuracy: 0.6645 - val_loss: 0.9841
# Epoch 33/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6712 - loss: 0.9401 - val_accuracy: 0.6552 - val_loss: 1.0352
# Epoch 34/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6712 - loss: 0.9376 - val_accuracy: 0.6894 - val_loss: 0.9176
# Epoch 35/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6764 - loss: 0.9312 - val_accuracy: 0.6803 - val_loss: 0.9407
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6792 - loss: 0.9169 - val_accuracy: 0.6737 - val_loss: 0.9715
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6747 - loss: 0.9221 - val_accuracy: 0.6980 - val_loss: 0.8846
# Epoch 38/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6791 - loss: 0.9190 - val_accuracy: 0.6763 - val_loss: 0.9643
# Epoch 39/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6808 - loss: 0.9157 - val_accuracy: 0.6804 - val_loss: 0.9408
# Epoch 40/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6857 - loss: 0.9030 - val_accuracy: 0.7022 - val_loss: 0.8774
# Epoch 41/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6867 - loss: 0.8892 - val_accuracy: 0.6739 - val_loss: 0.9996
# Epoch 42/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6854 - loss: 0.8882 - val_accuracy: 0.6826 - val_loss: 0.9338
# Epoch 43/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6913 - loss: 0.8847 - val_accuracy: 0.6957 - val_loss: 0.9069
# Epoch 44/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6974 - loss: 0.8700 - val_accuracy: 0.7013 - val_loss: 0.8785
# Epoch 45/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6879 - loss: 0.8871 - val_accuracy: 0.7157 - val_loss: 0.8356
# Epoch 46/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6908 - loss: 0.8755 - val_accuracy: 0.6841 - val_loss: 0.9652
# Epoch 47/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6903 - loss: 0.8723 - val_accuracy: 0.6849 - val_loss: 0.9510
# Epoch 48/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6941 - loss: 0.8758 - val_accuracy: 0.6975 - val_loss: 0.9032
# Epoch 49/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6987 - loss: 0.8536 - val_accuracy: 0.7052 - val_loss: 0.8932
# Epoch 50/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7027 - loss: 0.8544 - val_accuracy: 0.6994 - val_loss: 0.9093

# %% [markdown]
# **Plotting Training and Validation Loss and Accuracy**

# %%
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()
# successfully overfit after epoch=10 >> v.good since we want to know which is the optimal point
# what can we do now? take entire dataset (adding validation) and run again for epoch=10
# but if we think we can do better, try to find when it's underfitting(?)
# since there are many noises eg. specific background, we can induce som variations using augmentation > so it cant cheat by just simply remembering pattern

# %% [markdown]
# **Test data evaluation**

# %%
best_model = keras.models.load_model("convnet_from_scratch.keras")

test_loss, test_acc = best_model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7152 - loss: 0.8201
# Test accuracy: 0.7095000147819519

# %% [markdown]
# ## Data augmentation addition
#
# Now, add a data augmentation step and compare model performance.

# %% [markdown]
# **Model building**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(32, 32, 3))

# Applying augmentation on the inputs
x = data_augmentation(inputs) #augment before normalizing > now the model won't see the same image twice
# but will be harder to train the network since it sees noisy data

# Normalization layer
x = layers.Rescaling(1./255)(x)

# Convolutional blocks and rest of the model
x = layers.Conv2D(32, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(10, activation='softmax')(x)

# Create the model
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 4, 4, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │          32,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 126,730 (495.04 KB)
#  Trainable params: 126,730 (495.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Compile and train the model**

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="aug_convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(train_images, train_labels, epochs=100,
                    validation_split=0.2, batch_size=256,
                    callbacks = callbacks, verbose=0)

# %% [markdown]
# **Plotting Training and Validation Loss and Accuracy**

# %%
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6c58d7191530> in <cell line: 0>()
#       1 # Assuming 'history' is the return value from model.fit()
# ----> 2 history_dict = history.history
#       3
#       4 # Extracting loss and accuracy history
#       5 train_loss = history_dict['loss']
#
# NameError: name 'history' is not defined

# %%
def print_best_val_loss_and_accuracy(history):
    history_dict = history.history

    # Find the index of the best validation loss
    best_val_loss_index = np.argmin(history_dict['val_loss'])

    # Retrieve the best validation loss
    best_val_loss = history_dict['val_loss'][best_val_loss_index]

    # Retrieve the validation accuracy corresponding to the best validation loss
    best_val_accuracy = history_dict['val_accuracy'][best_val_loss_index]

    print(f"Best Validation Loss: {best_val_loss}")
    print(f"Validation Accuracy at Best Loss: {best_val_accuracy}")

# %%
print_best_val_loss_and_accuracy(history)
# Out:
# Best Validation Loss: 0.7647018432617188
# Validation Accuracy at Best Loss: 0.7497000098228455

# %%
best_model = keras.models.load_model("aug_convnet_from_scratch.keras")

test_loss, test_acc = best_model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7799 - accuracy: 0.7431
# Test accuracy: 0.7430999875068665

# %% [markdown]
# ## Experiment with more data augmentation
# Try experimenting with adding more data augmentation techniques

# %%
# Enhanced data augmentation (again, but more complex)
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal", input_shape=(32, 32, 3)),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
        layers.RandomContrast(0.1),  # Adjusts the contrast
        layers.RandomTranslation(height_factor=0.1, width_factor=0.1),  # Translates the image
        # Potentially add more augmentation techniques here
    ]
)

inputs = keras.Input(shape=(32, 32, 3))

# Applying enhanced augmentation on the inputs
x = data_augmentation(inputs)

# Continue with normalization and the rest of your model
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(32, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(10, activation='softmax')(x)

# Create the model
model = keras.Model(inputs=inputs, outputs=outputs)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="more_aug_convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(train_images, train_labels, epochs=100,
                    validation_split=0.2, batch_size=256,
                    callbacks = callbacks)
# Out:
# Epoch 1/100
# 157/157 [==============================] - 4s 9ms/step - loss: 1.9314 - accuracy: 0.2862 - val_loss: 1.6308 - val_accuracy: 0.4076
# Epoch 2/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.6600 - accuracy: 0.3984 - val_loss: 1.5745 - val_accuracy: 0.4246
# Epoch 3/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.5656 - accuracy: 0.4332 - val_loss: 1.6197 - val_accuracy: 0.4332
# Epoch 4/100
# 157/157 [==============================] - 1s 8ms/step - loss: 1.4998 - accuracy: 0.4578 - val_loss: 1.3511 - val_accuracy: 0.5161
# Epoch 5/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.4496 - accuracy: 0.4829 - val_loss: 1.4215 - val_accuracy: 0.5145
# Epoch 6/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.4104 - accuracy: 0.4951 - val_loss: 1.3902 - val_accuracy: 0.5224
# Epoch 7/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.3735 - accuracy: 0.5103 - val_loss: 1.3003 - val_accuracy: 0.5511
# Epoch 8/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.3351 - accuracy: 0.5247 - val_loss: 1.3423 - val_accuracy: 0.5506
# Epoch 9/100
# 157/157 [==============================] - 1s 8ms/step - loss: 1.3157 - accuracy: 0.5345 - val_loss: 1.2525 - val_accuracy: 0.5593
# Epoch 10/100
# 157/157 [==============================] - 1s 8ms/step - loss: 1.2962 - accuracy: 0.5395 - val_loss: 1.2494 - val_accuracy: 0.5642
# Epoch 11/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.2594 - accuracy: 0.5557 - val_loss: 1.1594 - val_accuracy: 0.5951
# Epoch 12/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.2445 - accuracy: 0.5620 - val_loss: 1.2236 - val_accuracy: 0.5860
# Epoch 13/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.2269 - accuracy: 0.5670 - val_loss: 1.2078 - val_accuracy: 0.5875
# Epoch 14/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.2100 - accuracy: 0.5738 - val_loss: 1.1094 - val_accuracy: 0.6186
# Epoch 15/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.1988 - accuracy: 0.5791 - val_loss: 1.1581 - val_accuracy: 0.6020
# Epoch 16/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.1852 - accuracy: 0.5836 - val_loss: 1.0800 - val_accuracy: 0.6250
# Epoch 17/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.1756 - accuracy: 0.5871 - val_loss: 1.2631 - val_accuracy: 0.5734
# Epoch 18/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.1479 - accuracy: 0.5975 - val_loss: 1.1777 - val_accuracy: 0.6059
# Epoch 19/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.1399 - accuracy: 0.5980 - val_loss: 1.1323 - val_accuracy: 0.6126
# Epoch 20/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.1348 - accuracy: 0.6031 - val_loss: 1.1748 - val_accuracy: 0.6109
# Epoch 21/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.1176 - accuracy: 0.6072 - val_loss: 1.0495 - val_accuracy: 0.6381
# Epoch 22/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.1021 - accuracy: 0.6127 - val_loss: 1.1665 - val_accuracy: 0.6061
# Epoch 23/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0939 - accuracy: 0.6129 - val_loss: 1.0260 - val_accuracy: 0.6450
# Epoch 24/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0934 - accuracy: 0.6163 - val_loss: 1.0060 - val_accuracy: 0.6563
# Epoch 25/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0710 - accuracy: 0.6237 - val_loss: 1.0154 - val_accuracy: 0.6533
# Epoch 26/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0804 - accuracy: 0.6193 - val_loss: 1.1482 - val_accuracy: 0.6162
# Epoch 27/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0667 - accuracy: 0.6268 - val_loss: 1.0346 - val_accuracy: 0.6491
# Epoch 28/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0530 - accuracy: 0.6322 - val_loss: 1.0271 - val_accuracy: 0.6542
# Epoch 29/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0523 - accuracy: 0.6301 - val_loss: 1.0237 - val_accuracy: 0.6515
# Epoch 30/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0412 - accuracy: 0.6352 - val_loss: 0.9652 - val_accuracy: 0.6675
# Epoch 31/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0343 - accuracy: 0.6383 - val_loss: 1.0248 - val_accuracy: 0.6576
# Epoch 32/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0246 - accuracy: 0.6396 - val_loss: 1.2028 - val_accuracy: 0.6070
# Epoch 33/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0264 - accuracy: 0.6396 - val_loss: 0.9399 - val_accuracy: 0.6799
# Epoch 34/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0171 - accuracy: 0.6467 - val_loss: 0.9695 - val_accuracy: 0.6730
# Epoch 35/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0032 - accuracy: 0.6506 - val_loss: 0.9729 - val_accuracy: 0.6723
# Epoch 36/100
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0031 - accuracy: 0.6476 - val_loss: 1.0169 - val_accuracy: 0.6594
# Epoch 37/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9984 - accuracy: 0.6508 - val_loss: 0.9272 - val_accuracy: 0.6832
# Epoch 38/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9829 - accuracy: 0.6548 - val_loss: 0.9833 - val_accuracy: 0.6710
# Epoch 39/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9839 - accuracy: 0.6557 - val_loss: 0.9421 - val_accuracy: 0.6832
# Epoch 40/100
# 157/157 [==============================] - 1s 8ms/step - loss: 0.9816 - accuracy: 0.6540 - val_loss: 0.8881 - val_accuracy: 0.6981
# Epoch 41/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9727 - accuracy: 0.6595 - val_loss: 1.1056 - val_accuracy: 0.6357
# Epoch 42/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9710 - accuracy: 0.6641 - val_loss: 0.8870 - val_accuracy: 0.6957
# Epoch 43/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9649 - accuracy: 0.6618 - val_loss: 0.9051 - val_accuracy: 0.6935
# Epoch 44/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9552 - accuracy: 0.6638 - val_loss: 1.0293 - val_accuracy: 0.6603
# Epoch 45/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9626 - accuracy: 0.6633 - val_loss: 0.9186 - val_accuracy: 0.6946
# Epoch 46/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9494 - accuracy: 0.6697 - val_loss: 0.9013 - val_accuracy: 0.6933
# Epoch 47/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9551 - accuracy: 0.6649 - val_loss: 1.0185 - val_accuracy: 0.6589
# Epoch 48/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9478 - accuracy: 0.6684 - val_loss: 0.9278 - val_accuracy: 0.6864
# Epoch 49/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9345 - accuracy: 0.6733 - val_loss: 1.0233 - val_accuracy: 0.6621
# Epoch 50/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9351 - accuracy: 0.6740 - val_loss: 0.9332 - val_accuracy: 0.6871
# Epoch 51/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9297 - accuracy: 0.6745 - val_loss: 0.9059 - val_accuracy: 0.6952
# Epoch 52/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9291 - accuracy: 0.6766 - val_loss: 0.9239 - val_accuracy: 0.6891
# Epoch 53/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9208 - accuracy: 0.6773 - val_loss: 0.9329 - val_accuracy: 0.6859
# Epoch 54/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9227 - accuracy: 0.6767 - val_loss: 0.8734 - val_accuracy: 0.7068
# Epoch 55/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9189 - accuracy: 0.6783 - val_loss: 0.9096 - val_accuracy: 0.6947
# Epoch 56/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9233 - accuracy: 0.6733 - val_loss: 0.9775 - val_accuracy: 0.6762
# Epoch 57/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9007 - accuracy: 0.6841 - val_loss: 0.8397 - val_accuracy: 0.7190
# Epoch 58/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9076 - accuracy: 0.6816 - val_loss: 0.8296 - val_accuracy: 0.7179
# Epoch 59/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9071 - accuracy: 0.6832 - val_loss: 0.8926 - val_accuracy: 0.7030
# Epoch 60/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8977 - accuracy: 0.6855 - val_loss: 0.8385 - val_accuracy: 0.7177
# Epoch 61/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8964 - accuracy: 0.6856 - val_loss: 0.8935 - val_accuracy: 0.7031
# Epoch 62/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8942 - accuracy: 0.6897 - val_loss: 0.8067 - val_accuracy: 0.7220
# Epoch 63/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8917 - accuracy: 0.6860 - val_loss: 0.8804 - val_accuracy: 0.7039
# Epoch 64/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8863 - accuracy: 0.6892 - val_loss: 0.9047 - val_accuracy: 0.6965
# Epoch 65/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8848 - accuracy: 0.6899 - val_loss: 0.8149 - val_accuracy: 0.7237
# Epoch 66/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8916 - accuracy: 0.6876 - val_loss: 0.8496 - val_accuracy: 0.7142
# Epoch 67/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8758 - accuracy: 0.6908 - val_loss: 0.8616 - val_accuracy: 0.7125
# Epoch 68/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8775 - accuracy: 0.6927 - val_loss: 0.8859 - val_accuracy: 0.7081
# Epoch 69/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8713 - accuracy: 0.6952 - val_loss: 0.9083 - val_accuracy: 0.6984
# Epoch 70/100
# 157/157 [==============================] - 1s 8ms/step - loss: 0.8708 - accuracy: 0.6975 - val_loss: 1.0306 - val_accuracy: 0.6707
# Epoch 71/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8667 - accuracy: 0.6980 - val_loss: 0.9288 - val_accuracy: 0.6985
# Epoch 72/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8642 - accuracy: 0.6988 - val_loss: 0.8645 - val_accuracy: 0.7133
# Epoch 73/100
# 157/157 [==============================] - 1s 8ms/step - loss: 0.8698 - accuracy: 0.6971 - val_loss: 0.7868 - val_accuracy: 0.7348
# Epoch 74/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8575 - accuracy: 0.6987 - val_loss: 0.8899 - val_accuracy: 0.7088
# Epoch 75/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8602 - accuracy: 0.6990 - val_loss: 0.9265 - val_accuracy: 0.6951
# Epoch 76/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8539 - accuracy: 0.7035 - val_loss: 0.8568 - val_accuracy: 0.7141
# Epoch 77/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8561 - accuracy: 0.6994 - val_loss: 0.8443 - val_accuracy: 0.7164
# Epoch 78/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8532 - accuracy: 0.7019 - val_loss: 0.8562 - val_accuracy: 0.7157
# Epoch 79/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8445 - accuracy: 0.7056 - val_loss: 0.8892 - val_accuracy: 0.7096
# Epoch 80/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8434 - accuracy: 0.7043 - val_loss: 0.9392 - val_accuracy: 0.6986
# Epoch 81/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8418 - accuracy: 0.7059 - val_loss: 0.8367 - val_accuracy: 0.7232
# Epoch 82/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8465 - accuracy: 0.7017 - val_loss: 0.7792 - val_accuracy: 0.7371
# Epoch 83/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8424 - accuracy: 0.7069 - val_loss: 0.9483 - val_accuracy: 0.6992
# Epoch 84/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8438 - accuracy: 0.7031 - val_loss: 0.8177 - val_accuracy: 0.7250
# Epoch 85/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8385 - accuracy: 0.7085 - val_loss: 0.8718 - val_accuracy: 0.7136
# Epoch 86/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8361 - accuracy: 0.7084 - val_loss: 0.8273 - val_accuracy: 0.7214
# Epoch 87/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8380 - accuracy: 0.7064 - val_loss: 0.8023 - val_accuracy: 0.7221
# Epoch 88/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8330 - accuracy: 0.7103 - val_loss: 0.8248 - val_accuracy: 0.7240
# Epoch 89/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8301 - accuracy: 0.7084 - val_loss: 0.8952 - val_accuracy: 0.7050
# Epoch 90/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8268 - accuracy: 0.7115 - val_loss: 0.8447 - val_accuracy: 0.7226
# Epoch 91/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8316 - accuracy: 0.7077 - val_loss: 0.8617 - val_accuracy: 0.7163
# Epoch 92/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8238 - accuracy: 0.7103 - val_loss: 0.8509 - val_accuracy: 0.7178
# Epoch 93/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8276 - accuracy: 0.7125 - val_loss: 0.8552 - val_accuracy: 0.7215
# Epoch 94/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8275 - accuracy: 0.7090 - val_loss: 0.8502 - val_accuracy: 0.7182
# Epoch 95/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8261 - accuracy: 0.7086 - val_loss: 0.8241 - val_accuracy: 0.7236
# Epoch 96/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8095 - accuracy: 0.7144 - val_loss: 0.8237 - val_accuracy: 0.7224
# Epoch 97/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8140 - accuracy: 0.7154 - val_loss: 0.7991 - val_accuracy: 0.7361
# Epoch 98/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8131 - accuracy: 0.7146 - val_loss: 0.8913 - val_accuracy: 0.7024
# Epoch 99/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8117 - accuracy: 0.7133 - val_loss: 0.7996 - val_accuracy: 0.7360
# Epoch 100/100
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8060 - accuracy: 0.7194 - val_loss: 0.8022 - val_accuracy: 0.7319

# %%
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()
# it's now worse than a simpler augmentation > lower general accuracy, more instability in validation loss (bc we have more noise)
# although it has higher validation accuracy at lowest loss
# the more noisy, the harder it is to find minimum >> we prefer smoother one
# goal == finding the model with best accuracy at lowest loss

# %%
print_best_val_loss_and_accuracy(history)
# Out:
# Best Validation Loss: 0.7791651487350464
# Validation Accuracy at Best Loss: 0.7371000051498413

# %%
best_model = keras.models.load_model("more_aug_convnet_from_scratch.keras")

test_loss, test_acc = best_model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7758 - accuracy: 0.7340
# Test accuracy: 0.734000027179718

# %% [markdown]
# ## What's next?
#
# To further increase the performance of our model, we could make some tweaks here and there, like icreasing the number of filters in the convolutional layers can help the model learn more complex features. Similarly, adjusting the number of neurons in the dense layers might improve learning capacity.
#
# However, at this stage, gains from such changes are likely going to marginal.
#
# Instead, there are two things that would likely boost performance:
#
# 1) More and better data! The data is greatly pixilated. Higher resolution data would allow us to build deeper models that generalize better.
#
# 2) More and better tricks! Next in next sessions, we'll learn about advanced computer vision techniques that can push performance even further.
